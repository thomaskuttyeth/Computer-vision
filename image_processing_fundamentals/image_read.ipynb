# %%
# using matplotlib, opencv, pillow, 

from matplotlib import pyplot as plt 
import numpy as np 
from skimage import io 
my_image = io.imread('/home/thomas/Pictures/pexels-errin-casano-2356045.jpg')

from skimage import img_as_float 
plt.imshow(my_image)
plt.show()

# %%
####################################################
# pillow 

import numpy as np 
from PIL import Image
img = Image.open('/home/thomas/Pictures/pexels-toni-cuenca-619419.jpg')
print(type(img)) 


print(img.format) 
img1 = np.asarray(img)
print(type(img1))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# <class 'numpy.ndarray'>

# %%
# creating a random image 

random_image = np.random.random([500,500]) 
plt.imshow(random_image) 
print(random_image)
print(random_image.min()) 



plt.imshow(my_image)
# Out:
# [[0.88090834 0.42439885 0.79216054 ... 0.66506926 0.38961716 0.40475067]
#  [0.80461691 0.75639636 0.72475037 ... 0.52809501 0.47223665 0.49411599]
#  [0.74560956 0.96349754 0.19458034 ... 0.03218877 0.99320148 0.3649975 ]
#  ...
#  [0.40975628 0.85398199 0.58709591 ... 0.04230145 0.13747805 0.31907192]
#  [0.25802906 0.86989801 0.06111119 ... 0.132799   0.02369395 0.2361623 ]
#  [0.01808182 0.58877386 0.90018471 ... 0.9274795  0.83300378 0.07089878]]
# 6.31847475340841e-07

# %%
my_float_img = img_as_float(my_image) 
plt.imshow(my_float_img)

# %%
dark_image = my_image* -0.45
plt.imshow(my_image)

# %%
my_image[10: 200, 10: 200, :] = [255, 0,0]
plt.imshow(my_image)

# %%
#####################################################
# matplotlib - plotting library 
# pyplot 

import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
img = mpimg.imread('/home/thomas/Pictures/pexels-toni-cuenca-619419.jpg')
print(type(img)) 
print(img.shape) 
plt.imshow(img) 
plt.colorbar() 
plt.show()
# Out:
# <class 'numpy.ndarray'>
# (3840, 5760, 3)

# %%
##########################################################
# scikit image - image processing library 
# geometric transformation 
# filtering 
# for traditional machine leaning 
import matplotlib.pyplot as plt
from skimage import io, img_as_float, img_as_ubyte
image = io.imread('/home/thomas/Pictures/pexels-toni-cuenca-619419.jpg') 
print(type(image))
plt.imshow(image)
# Out:
# <class 'numpy.ndarray'>
